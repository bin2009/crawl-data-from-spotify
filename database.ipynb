# %% [markdown]
# ### get info

# %%
import os
import pandas as pd
from unidecode import unidecode

# Đường dẫn đến thư mục chứa các file CSV
merge_dir = 'D:/DUT/NAM4-KI1/PBL6/CRAWL/crawl-data-from-spotify/Merge'
array_artist = set()  # Sử dụng set để tránh trùng lặp

# Liệt kê tất cả các file trong thư mục
files = [f for f in os.listdir(merge_dir) if f.endswith('.csv')]

# Đọc và xử lý từng file CSV
for file in files:
    print(f"Đang xử lý file: {file}")
    file_path = os.path.join(merge_dir, file)
    df = pd.read_csv(file_path)
    
    # Lặp qua từng hàng trong DataFrame
    for index, row in df.iterrows():
        if '||' in row['Artists']:
            artists = row['Artists'].split('||')
            for art in artists:
                art = art.split('(')[0].strip()
                art = unidecode(art)  # Chuyển sang dạng chữ không dấu
                array_artist.add(art)  # Thêm nghệ sĩ vào set để tránh trùng lặp
        else:
            artists = row['Artists'].split('(')[0].strip()
            artists = unidecode(artists)  # Chuyển sang dạng chữ không dấu
            array_artist.add(artists)

# Chuyển đổi set thành danh sách
array_artist = list(array_artist)

# Tạo DataFrame từ danh sách nghệ sĩ
df_artists = pd.DataFrame(array_artist, columns=['Name'])

# Đường dẫn đến file Excel để xuất
output_excel_path = 'D:/DUT/NAM4-KI1/PBL6/CRAWL/crawl-data-from-spotify/Data-Artist/AAA.xlsx'

# Xuất DataFrame ra file Excel
df_artists.to_excel(output_excel_path, index=False)

print(f"Danh sách các nghệ sĩ đã được xuất ra file: {output_excel_path}")
# Out:
# Đang xử lý file: HoangThuyLinh.csv
# Đang xử lý file: HoangTon.csv
# Đang xử lý file: NooPhuocThinh.csv
# Đang xử lý file: PhanManhQuynh.csv
# Đang xử lý file: SonTungMTP.csv
# Đang xử lý file: SOOBIN.csv
# Danh sách các nghệ sĩ đã được xuất ra file: D:/DUT/NAM4-KI1/PBL6/CRAWL/crawl-data-from-spotify/Data-Artist/AAA.xlsx

# %% [markdown]
# ### FULL

# %%
# import pandas as pd
# import uuid

# # Load artist information
# nameArtist = 'SonTungMTP'
# artists = pd.read_csv('D:/DUT/NAM4-KI1/PBL6/CRAWL/crawl-data-from-spotify/Data-Artist/inf.csv')

# # SQL INSERT template for the Artist table
# insert_sql_artist = 'INSERT INTO "Artist" ("id", "id2", "name", "avatar", "bio", "createdAt", "updatedAt") VALUES\n'

# # Prepare artist insert values and a mapping between id2 and id (UUID)
# values_artist = []
# artist_id_map = {}
# for index3, row3 in artists.iterrows():
#     artist_uuid = str(uuid.uuid4()) 
#     artist_id2 = row3['Artist ID']
#     name = row3[' Artist Name'].strip()
#     avatar = row3[' Images'].split('||')[1].split('(')[0].strip()
#     bio = 'Null'
#     values_artist.append(f"('{artist_uuid}', '{artist_id2}', '{name}', '{avatar}', '{bio}', NOW(), NOW())")
    
#     # Store the mapping for use later
#     artist_id_map[artist_id2] = artist_uuid

# # Load album and track data for the artist
# df = pd.read_csv(f'D:/DUT/NAM4-KI1/PBL6/CRAWL/crawl-data-from-spotify/Merge/{nameArtist}.csv')

# # SQL INSERT templates for Album, AlbumImage, Song, and ArtistSong tables
# insert_sql_album = 'INSERT INTO "Album" ("albumId", "albumId2", "title", "releaseDate", "albumType", "createdAt", "updatedAt") VALUES\n'
# insert_sql_album_image = 'INSERT INTO "AlbumImage" ("albumId", "albumId2", "image", "size", "createdAt", "updatedAt") VALUES\n'
# insert_sql_track = 'INSERT INTO "Song" ("id", "id2", "albumId", "albumId2", "title", "duration", "lyric", "filePathAudio", "privacy", "uploadUserId", "createdAt", "updatedAt") VALUES\n'
# insert_sql_artist_song = 'INSERT INTO "ArtistSong" ("songId", "songId2", "artistId", "artistId2", "main", "createdAt", "updatedAt") VALUES\n'

# # Prepare insert values for albums, album images, tracks, and artist-song relationships
# values_album = []
# values_album_image = []
# values_track = []
# values_track_artist = []

# # Remove duplicate albums
# unique_album = df.drop_duplicates(subset=['AlbumID'])

# for index, row in unique_album.iterrows():
#     # Album details
#     albumId = str(uuid.uuid4()) 
#     albumIdTemp = row['AlbumID']
    
#     values_album.append(f"('{albumId}', '{albumIdTemp}', '{row['Album']}', '{row['ReleaseDate']}', '{row['AlbumType'].lower()}', NOW(), NOW())")

#     # Album images
#     images = row['AlbumImage'].split('||')
#     for img in images:
#         img_url, img_size = img.split('(')
#         img_url = img_url.strip()
#         img_size = img_size.strip().split('size:')[1].strip().split(')')[0].strip()
#         values_album_image.append(f"('{albumId}', '{albumIdTemp}', '{img_url}', '{img_size}', NOW(), NOW())")

#     # Tracks associated with the current album
#     tracks_in_album = df[df['AlbumID'] == albumIdTemp]
#     for _, track in tracks_in_album.iterrows():
#         trackId = str(uuid.uuid4())
#         values_track.append(f"('{trackId}', '{track['TrackID']}', '{albumId}', '{albumIdTemp}', '{track['TrackName']}', '{track['TrackDuration']}', 'lyric', '{track['audio_path']}', FALSE, 'Null', NOW(), NOW())")

#         # Associate track with artists
#         artistNames = track['ArtistsName'].split('||')
        
#         # Handle artist-song relation based on artistNames length
#         if len(artistNames) == 1:
#             # Only one artist, set main to TRUE
#             artist_name = artistNames[0]
#             artId2 = artist_name.split('(ID:')[1].split(')')[0].strip()
#             artistId = artist_id_map.get(artId2, 'Unknown')  # Use artist_id_map to fetch the UUID
#             values_track_artist.append(f"('{trackId}', '{track['TrackID']}', '{artistId}', '{artId2}', TRUE, NOW(), NOW())")
#         else:
#             # Multiple artists, first one is main, others are not
#             for i, artist in enumerate(artistNames):
#                 artId2 = artist.split('(ID:')[1].split(')')[0].strip()
#                 artistId = artist_id_map.get(artId2, 'Unknown')  # Fetch UUID from the map
#                 main = 'TRUE' if i == 0 else 'FALSE'
#                 values_track_artist.append(f"('{trackId}', '{track['TrackID']}', '{artistId}', '{artId2}', {main}, NOW(), NOW())")

# # Combine values for SQL insert queries
# insert_sql_artist += ",\n".join(values_artist) + ";"
# insert_sql_album += ",\n".join(values_album) + ";"
# insert_sql_album_image += ",\n".join(values_album_image) + ";"
# insert_sql_track += ",\n".join(values_track) + ";"
# insert_sql_artist_song += ",\n".join(values_track_artist) + ";"

# # Save the SQL queries to a file
# sql_file_path = f'D:/DUT/NAM4-KI1/PBL6/CRAWL/crawl-data-from-spotify/SQL2/{nameArtist}_sql.sql'

# with open(sql_file_path, 'w', encoding='utf-8') as file:
#     file.write(insert_sql_artist)
#     file.write("\n\n\n\n")
#     file.write(insert_sql_album)
#     file.write("\n\n\n\n")
#     file.write(insert_sql_album_image)
#     file.write("\n\n\n\n")
#     file.write(insert_sql_track)
#     file.write("\n\n\n\n")
#     file.write(insert_sql_artist_song)

# %% [markdown]
# ### OK

# %%
import pandas as pd
import uuid

# Load artist information
nameArtist = 'SonTungMTP'
artists = pd.read_csv('D:/DUT/NAM4-KI1/PBL6/CRAWL/crawl-data-from-spotify/Data-Artist/inf.csv')

# SQL INSERT template for the Artist table
insert_sql_artist = 'INSERT INTO "Artist" ("id", "name", "avatar", "bio", "createdAt", "updatedAt") VALUES\n'

# Prepare artist insert values and a mapping between id2 and id (UUID)
values_artist = []
artist_id_map = {}
for index3, row3 in artists.iterrows():
    artist_uuid = str(uuid.uuid4()) 
    artist_id2 = row3['Artist ID']
    name = row3[' Artist Name'].strip()
    avatar = row3[' Images'].split('||')[1].split('(')[0].strip()
    bio = 'Null'
    values_artist.append(f"('{artist_uuid}', '{name}', '{avatar}', '{bio}', NOW(), NOW())")
    
    # Store the mapping for use later
    artist_id_map[artist_id2] = artist_uuid




# Load album and track data for the artist
df = pd.read_csv(f'D:/DUT/NAM4-KI1/PBL6/CRAWL/crawl-data-from-spotify/Merge/{nameArtist}.csv')

# SQL INSERT templates for Album, AlbumImage, Song, and ArtistSong tables
insert_sql_album = 'INSERT INTO "Album" ("albumId",  "title", "releaseDate",  "coverImage", "albumType", "createdAt", "updatedAt") VALUES\n'
insert_sql_album_image = 'INSERT INTO "AlbumImage" ("albumId", "image", "size", "createdAt", "updatedAt") VALUES\n'
insert_sql_track = 'INSERT INTO "Song" ("id", "albumId", "title", "duration", "lyric", "filePathAudio", "privacy", "uploadUserId", "createdAt", "updatedAt") VALUES\n'
insert_sql_artist_song = 'INSERT INTO "ArtistSong" ("songId", "artistId", "main", "createdAt", "updatedAt") VALUES\n'

# Prepare insert values for albums, album images, tracks, and artist-song relationships
values_album = []
values_album_image = []
values_track = []
values_track_artist = []

# Remove duplicate albums
unique_album = df.drop_duplicates(subset=['AlbumID'])

for index, row in unique_album.iterrows():
    # Album details
    albumId = str(uuid.uuid4()) 
    albumIdTemp = row['AlbumID']
    
    values_album.append(f"('{albumId}', '{row['Album']}', '{row['ReleaseDate']}', '{row['AlbumImage']}','{row['AlbumType'].lower()}', NOW(), NOW())")

    # Album images
    images = row['AlbumImage'].split('||')
    for img in images:
        img_url, img_size = img.split('(')
        img_url = img_url.strip()
        img_size = img_size.strip().split('size:')[1].strip().split(')')[0].strip()
        values_album_image.append(f"('{albumId}', '{img_url}', '{img_size}', NOW(), NOW())")

    # Tracks associated with the current album
    tracks_in_album = df[df['AlbumID'] == albumIdTemp]
    for _, track in tracks_in_album.iterrows():
        trackId = str(uuid.uuid4())
        values_track.append(f"('{trackId}', '{albumId}', '{track['TrackName']}', '{track['TrackDuration']}', 'lyric', '{track['audio_path']}', FALSE, 'Null', NOW(), NOW())")

        # Associate track with artists
        artistNames = track['ArtistsName'].split('||')
        
        # Handle artist-song relation based on artistNames length
        if len(artistNames) == 1:
            # Only one artist, set main to TRUE
            artist_name = artistNames[0]
            artId2 = artist_name.split('(ID:')[1].split(')')[0].strip()
            artistId = artist_id_map.get(artId2, 'Unknown')  # Use artist_id_map to fetch the UUID
            values_track_artist.append(f"('{trackId}',  '{artistId}', , TRUE, NOW(), NOW())")
        else:
            # Multiple artists, first one is main, others are not
            for i, artist in enumerate(artistNames):
                artId2 = artist.split('(ID:')[1].split(')')[0].strip()
                artistId = artist_id_map.get(artId2, 'Unknown')  # Fetch UUID from the map
                main = 'TRUE' if i == 0 else 'FALSE'
                values_track_artist.append(f"('{trackId}', '{artistId}', {main}, NOW(), NOW())")

# Combine values for SQL insert queries
insert_sql_artist += ",\n".join(values_artist) + ";"
insert_sql_album += ",\n".join(values_album) + ";"
insert_sql_album_image += ",\n".join(values_album_image) + ";"
insert_sql_track += ",\n".join(values_track) + ";"
insert_sql_artist_song += ",\n".join(values_track_artist) + ";"

# Save the SQL queries to a file
sql_file_path = f'D:/DUT/NAM4-KI1/PBL6/CRAWL/crawl-data-from-spotify/SQL2/{nameArtist}_sql.sql'

with open(sql_file_path, 'w', encoding='utf-8') as file:
    file.write(insert_sql_artist)
    file.write("\n\n\n\n")
    file.write(insert_sql_album)
    file.write("\n\n\n\n")
    file.write(insert_sql_album_image)
    file.write("\n\n\n\n")
    file.write(insert_sql_track)
    file.write("\n\n\n\n")
    file.write(insert_sql_artist_song)

# %%
df = pd.read_csv(f'D:/DUT/NAM4-KI1/PBL6/CRAWL/crawl-data-from-spotify/Merge/{nameArtist}.csv')
df.head()
# Out:
#                   AlbumID                                          Album  \
# 0  2UZre9rniPNke0bwRs1SMf  Sky Tour (Original Motion Picture Soundtrack)
# 1  2UZre9rniPNke0bwRs1SMf  Sky Tour (Original Motion Picture Soundtrack)
# 2  2UZre9rniPNke0bwRs1SMf  Sky Tour (Original Motion Picture Soundtrack)
# 3  2UZre9rniPNke0bwRs1SMf  Sky Tour (Original Motion Picture Soundtrack)
# 4  2UZre9rniPNke0bwRs1SMf  Sky Tour (Original Motion Picture Soundtrack)
#
#   ReleaseDate                                     Artists AlbumType  \
# 0  2020-06-12  Sơn Tùng M-TP (ID: 5dfZ5uSmzR7VQK0udbAVpf)     album
# 1  2020-06-12  Sơn Tùng M-TP (ID: 5dfZ5uSmzR7VQK0udbAVpf)     album
# 2  2020-06-12  Sơn Tùng M-TP (ID: 5dfZ5uSmzR7VQK0udbAVpf)     album
# 3  2020-06-12  Sơn Tùng M-TP (ID: 5dfZ5uSmzR7VQK0udbAVpf)     album
# 4  2020-06-12  Sơn Tùng M-TP (ID: 5dfZ5uSmzR7VQK0udbAVpf)     album
#
#    TotalTracks                                         AlbumImage  \
# 0            8  https://i.scdn.co/image/ab67616d0000b2738a0966...
# 1            8  https://i.scdn.co/image/ab67616d0000b2738a0966...
# 2            8  https://i.scdn.co/image/ab67616d0000b2738a0966...
# 3            8  https://i.scdn.co/image/ab67616d0000b2738a0966...
# 4            8  https://i.scdn.co/image/ab67616d0000b2738a0966...
#
#                   TrackID                                     TrackName  \
# 0  2clSWs3MlXkGHNbJMqkFgV                              Sky Tour (Intro)
# 1  5VEbCBsWrWI2I5OQhDrNJF                  Chạy Ngay Đi - Sky Tour 2019
# 2  1bmqD4QuCN2p9LR9J8YZKe  Chúng Ta Không Thuộc Về Nhau - Sky Tour 2019
# 3  6g8pvcdm71gk7Hmtun3cf8                      Lạc Trôi - Sky Tour 2019
# 4  7jPyT2shQ4Ruwqr5MtETDF                   Remember Me - Sky Tour 2019
#
#                                          ArtistsName  DiscNumber  TrackNumber  \
# 0         Sơn Tùng M-TP (ID: 5dfZ5uSmzR7VQK0udbAVpf)           1            1
# 1         Sơn Tùng M-TP (ID: 5dfZ5uSmzR7VQK0udbAVpf)           1            2
# 2         Sơn Tùng M-TP (ID: 5dfZ5uSmzR7VQK0udbAVpf)           1            3
# 3         Sơn Tùng M-TP (ID: 5dfZ5uSmzR7VQK0udbAVpf)           1            4
# 4  Sơn Tùng M-TP (ID: 5dfZ5uSmzR7VQK0udbAVpf) || ...           1            5
#
#    TrackDuration            PreviewUrl  \
# 0         149077  No preview available
# 1         309504  No preview available
# 2         247594  No preview available
# 3         293890  No preview available
# 4         203433  No preview available
#
#                                           audio_path
# 0  https://audiomelodies.nyc3.digitaloceanspaces....
# 1  https://audiomelodies.nyc3.digitaloceanspaces....
# 2  https://audiomelodies.nyc3.digitaloceanspaces....
# 3  https://audiomelodies.nyc3.digitaloceanspaces....
# 4  https://audiomelodies.nyc3.digitaloceanspaces....

# %% [markdown]
# ### ARRAY

# %%
import pandas as pd
import uuid

# Load artist information
nameArtist = 'SonTungMTP'
artists = pd.read_csv('D:/DUT/NAM4-KI1/PBL6/CRAWL/crawl-data-from-spotify/Data-Artist/inf.csv')

# SQL INSERT template for the Artist table
insert_sql_artist = 'INSERT INTO "Artist" ("id", "name", "avatar", "bio", "createdAt", "updatedAt") VALUES\n'

# Prepare artist insert values and a mapping between id2 and id (UUID)
values_artist = []
artist_id_map = {}
for index3, row3 in artists.iterrows():
    artist_uuid = str(uuid.uuid4()) 
    artist_id2 = row3['Artist ID']
    name = row3[' Artist Name'].strip()
    avatar = row3[' Images'].split('||')[1].split('(')[0].strip()
    bio = 'Null'
    values_artist.append(f"('{artist_uuid}', '{name}', '{avatar}', '{bio}', NOW(), NOW())")
    
    # Store the mapping for use later
    artist_id_map[artist_id2] = artist_uuid

artist_sql_file_path = f'D:/DUT/NAM4-KI1/PBL6/CRAWL/crawl-data-from-spotify/SQL2/artist_sql.sql'
insert_sql_artist += ",\n".join(values_artist) + ";"
with open(artist_sql_file_path, 'w', encoding='utf-8') as file:
        file.write(insert_sql_artist)
        file.write("\n\n\n\n")


nameArtists = ['SonTungMTP', 'SOOBIN', 'PhanManhQuynh', 'NooPhuocThinh', 'HoangTon', 'HoangThuyLinh']

for nameArtist in nameArtists:
    # Load album and track data for the artist
    df = pd.read_csv(f'D:/DUT/NAM4-KI1/PBL6/CRAWL/crawl-data-from-spotify/Merge/{nameArtist}.csv')

    # SQL INSERT templates for Album, AlbumImage, Song, and ArtistSong tables
    insert_sql_album = 'INSERT INTO "Album" ("albumId",  "title", "releaseDate", "albumType", "createdAt", "updatedAt") VALUES\n'
    insert_sql_album_image = 'INSERT INTO "AlbumImage" ("albumId", "image", "size", "createdAt", "updatedAt") VALUES\n'
    insert_sql_track = 'INSERT INTO "Song" ("id", "albumId", "title", "duration", "lyric", "filePathAudio", "privacy", "uploadUserId", "createdAt", "updatedAt") VALUES\n'
    insert_sql_artist_song = 'INSERT INTO "ArtistSong" ("songId", "artistId", "main", "createdAt", "updatedAt") VALUES\n'

    # Prepare insert values for albums, album images, tracks, and artist-song relationships
    values_album = []
    values_album_image = []
    values_track = []
    values_track_artist = []

    # Remove duplicate albums
    unique_album = df.drop_duplicates(subset=['AlbumID'])

    for index, row in unique_album.iterrows():
        # Album details
        albumId = str(uuid.uuid4()) 
        albumIdTemp = row['AlbumID']
        
        values_album.append(f"('{albumId}', '{row['Album']}', '{row['ReleaseDate']}', '{row['AlbumType'].lower()}', NOW(), NOW())")

        # Album images
        images = row['AlbumImage'].split('||')
        for img in images:
            if '(' in img:
                img_url, img_size = img.split('(')
                img_url = img_url.strip()
                img_size = img_size.strip().split('size:')[1].strip().split(')')[0].strip()
                values_album_image.append(f"('{albumId}', '{row['AlbumID']}', '{img_url}', '{img_size}', NOW(), NOW())")
            else:
                # Handle case where image string does not contain '('
                img_url = img.strip()
                img_size = 'Unknown'  # or any default value you prefer
                values_album_image.append(f"('{albumId}', '{row['AlbumID']}', '{img_url}', '{img_size}', NOW(), NOW())")

                
            # img_url, img_size = img.split('(')
            # img_url = img_url.strip()
            # img_size = img_size.strip().split('size:')[1].strip().split(')')[0].strip()
            # values_album_image.append(f"('{albumId}', '{img_url}', '{img_size}', NOW(), NOW())")

        # Tracks associated with the current album
        tracks_in_album = df[df['AlbumID'] == albumIdTemp]
        for _, track in tracks_in_album.iterrows():
            trackId = str(uuid.uuid4())
            values_track.append(f"('{trackId}', '{albumId}', '{track['TrackName']}', '{track['TrackDuration']}', 'lyric', '{track['audio_path']}', FALSE, 'Null', NOW(), NOW())")

            # Associate track with artists
            # artistNames = track['ArtistsName'].split('||')
            artistNames = track['ArtistsName']
            if pd.isna(artistNames):
                continue  # Skip if ArtistsName is NaN
            artistNames = artistNames.split('||')

            # Handle artist-song relation based on artistNames length
            if len(artistNames) == 1:
                # Only one artist, set main to TRUE
                artist_name = artistNames[0]
                artId2 = artist_name.split('(ID:')[1].split(')')[0].strip()
                artistId = artist_id_map.get(artId2, 'Unknown')  # Use artist_id_map to fetch the UUID
                values_track_artist.append(f"('{trackId}',  '{artistId}', , TRUE, NOW(), NOW())")
            else:
                # Multiple artists, first one is main, others are not
                for i, artist in enumerate(artistNames):
                    artId2 = artist.split('(ID:')[1].split(')')[0].strip()
                    artistId = artist_id_map.get(artId2, 'Unknown')  # Fetch UUID from the map
                    main = 'TRUE' if i == 0 else 'FALSE'
                    values_track_artist.append(f"('{trackId}', '{artistId}', {main}, NOW(), NOW())")

    # Combine values for SQL insert queries
    insert_sql_album += ",\n".join(values_album) + ";"
    insert_sql_album_image += ",\n".join(values_album_image) + ";"
    insert_sql_track += ",\n".join(values_track) + ";"
    insert_sql_artist_song += ",\n".join(values_track_artist) + ";"

    # Save the SQL queries to a file
    sql_file_path = f'D:/DUT/NAM4-KI1/PBL6/CRAWL/crawl-data-from-spotify/SQL2/{nameArtist}_sql.sql'

    with open(sql_file_path, 'w', encoding='utf-8') as file:
        file.write(insert_sql_album)
        file.write("\n\n\n\n")
        file.write(insert_sql_album_image)
        file.write("\n\n\n\n")
        file.write(insert_sql_track)
        file.write("\n\n\n\n")
        file.write(insert_sql_artist_song)

# %% [markdown]
# ### Gộp final

# %%
# Load artist information
artists = pd.read_csv('D:/DUT/NAM4-KI1/PBL6/CRAWL/crawl-data-from-spotify/Data-Artist/inf.csv')
artists.head()

# # SQL INSERT template for the Artist table
# insert_sql_artist = 'INSERT INTO "Artist" ("id", "name", "avatar", "bio", "createdAt", "updatedAt") VALUES\n'

# # Prepare artist insert values and a mapping between id2 and id (UUID)
# values_artist = []
# artist_id_map = {}
# for index3, row3 in artists.iterrows():
#     artist_uuid = str(uuid.uuid4()) 
#     artist_id2 = row3['Artist ID']
# Out:
#                 Artist ID     Artist Name   Popularity  \
# 0  4jQZaxfgwiUJFQagCyZNV4      Ricky Star           41
# 1  70swmqj7c3SHkkdf2SrSUy           LyHan           37
# 2  6d0dLenjy5CnR5ZMn2agiV          GREY D           62
# 3  0cAcRTWMSeuezcHpxInChD   BeepBeepChild           21
# 4  0qAJ604EZMbkbpZ9NN6W6d          WOKEUP           51
#
#                          Genres  \
# 0   v-pop || vietnamese hip hop
# 1
# 2                         v-pop
# 3
# 4
#
#                                               Images
# 0   https://i.scdn.co/image/ab6761610000e5ebe7012...
# 1   https://i.scdn.co/image/ab6761610000e5ebc6db3...
# 2   https://i.scdn.co/image/ab6761610000e5ebd23b0...
# 3   https://i.scdn.co/image/ab6761610000e5eb6b9a8...
# 4   https://i.scdn.co/image/ab6761610000e5eb5d82b...

# %%
import pandas as pd
import uuid

# Load artist information
artists = pd.read_csv('D:/DUT/NAM4-KI1/PBL6/CRAWL/crawl-data-from-spotify/Data-Artist/inf.csv')

# SQL INSERT template for the Artist table
insert_sql_artist = 'INSERT INTO "Artist" ("id", "name", "avatar", "bio", "createdAt", "updatedAt") VALUES\n'



# Prepare artist insert values and a mapping between id2 and id (UUID)
values_artist = []
artist_id_map = {}
for index3, row3 in artists.iterrows():
    artist_uuid = str(uuid.uuid4()) 
    artist_id2 = row3['Artist ID']
    name = row3[' Artist Name'].strip()
    # avatar = row3[' Images'].split('||')[1].split('(')[0].strip()
    images = row3[' Images'].split('||')
    if len(images) > 1:
        avatar = images[1].split('(')[0].strip()
    else:
        avatar = 'Unknown'
    bio = 'Null'
    values_artist.append(f"('{artist_uuid}', '{name}', '{avatar}', '{bio}', NOW(), NOW())")
    
    # Store the mapping for use later
    artist_id_map[artist_id2] = artist_uuid


# print(artist_id_map)


# Save the SQL queries to a file
sql_file_path = f'D:/DUT/NAM4-KI1/PBL6/CRAWL/crawl-data-from-spotify/SQL2/fullsql.sql'

insert_sql_artist += ",\n".join(values_artist) + ";"
with open(sql_file_path, 'w', encoding='utf-8') as file:
        file.write(insert_sql_artist)
        file.write("\n\n\n\n")


nameArtists = ['SonTungMTP', 'SOOBIN', 'PhanManhQuynh', 'NooPhuocThinh', 'HoangTon', 'HoangThuyLinh']

for nameArtist in nameArtists:
    # Load album and track data for the artist
    df = pd.read_csv(f'D:/DUT/NAM4-KI1/PBL6/CRAWL/crawl-data-from-spotify/Merge/{nameArtist}.csv')

    # SQL INSERT templates for Album, AlbumImage, Song, and ArtistSong tables
    insert_sql_album = 'INSERT INTO "Album" ("albumId",  "title", "releaseDate", "albumType", "createdAt", "updatedAt") VALUES\n'
    insert_sql_album_image = 'INSERT INTO "AlbumImage" ("albumId", "image", "size", "createdAt", "updatedAt") VALUES\n'
    insert_sql_track = 'INSERT INTO "Song" ("id", "albumId", "title", "duration", "lyric", "filePathAudio", "privacy", "uploadUserId", "createdAt", "updatedAt") VALUES\n'
    insert_sql_artist_song = 'INSERT INTO "ArtistSong" ("songId", "artistId", "main", "createdAt", "updatedAt") VALUES\n'

    # Prepare insert values for albums, album images, tracks, and artist-song relationships
    values_album = []
    values_album_image = []
    values_track = []
    values_track_artist = []

    # Remove duplicate albums
    unique_album = df.drop_duplicates(subset=['AlbumID'])

    for index, row in unique_album.iterrows():
        # Album details
        albumId = str(uuid.uuid4()) 
        albumIdTemp = row['AlbumID']
        
        values_album.append(f"('{albumId}', '{row['Album']}', '{row['ReleaseDate']}', '{row['AlbumType'].lower()}', NOW(), NOW())")

        # Album images
        images = row['AlbumImage'].split('||')
        for img in images:
            if '(' in img:
                img_url, img_size = img.split('(')
                img_url = img_url.strip()
                img_size = img_size.strip().split('size:')[1].strip().split(')')[0].strip()
                values_album_image.append(f"('{albumId}', '{img_url}', '{img_size}', NOW(), NOW())")
            else:
                # Handle case where image string does not contain '('
                img_url = img.strip()
                img_size = 0  # or any default value you prefer
                values_album_image.append(f"('{albumId}', '{row['AlbumID']}', '{img_url}', '{img_size}', NOW(), NOW())")

                
            # img_url, img_size = img.split('(')
            # img_url = img_url.strip()
            # img_size = img_size.strip().split('size:')[1].strip().split(')')[0].strip()
            # values_album_image.append(f"('{albumId}', '{img_url}', '{img_size}', NOW(), NOW())")

        # Tracks associated with the current album
        tracks_in_album = df[df['AlbumID'] == albumIdTemp]
        for _, track in tracks_in_album.iterrows():
            trackId = str(uuid.uuid4())
            values_track.append(f"('{trackId}', '{albumId}', '{track['TrackName']}', '{track['TrackDuration']}', 'lyric', '{track['audio_path']}', FALSE, 'Null', NOW(), NOW())")

            # Associate track with artists
            # artistNames = track['ArtistsName'].split('||')
            artistNames = track['ArtistsName']
            if pd.isna(artistNames):
                continue  # Skip if ArtistsName is NaN
            if "||" in artistNames:

                artistNames = artistNames.split('||')
                # Multiple artists, first one is main, others are not
                for i, artist in enumerate(artistNames):
                    artId2 = artist.split('(ID:')[1].split(')')[0].strip()
                    artistId = artist_id_map.get(artId2, 'Unknown')  # Fetch UUID from the map
                    main = 'TRUE' if i == 0 else 'FALSE'
                    values_track_artist.append(f"('{trackId}', '{artistId}', {main}, NOW(), NOW())")
            else: 
                artId2 = artistNames.split('(ID:')[1].split(')')[0].strip()
                artistId = artist_id_map.get(artId2, 'Unknown')  # Use artist_id_map to fetch the UUID
                values_track_artist.append(f"('{trackId}',  '{artistId}', TRUE, NOW(), NOW())")

            print(artistNames)
            # if pd.isna(artistNames):
            #     continue  # Skip if ArtistsName is NaN
            # artistNames = artistNames.split('||')

            # # Handle artist-song relation based on artistNames length
            # if len(artistNames) == 1:
            #     # Only one artist, set main to TRUE
            #     artist_name = artistNames[0]
            #     # print(artist_name)
            #     artId2 = artist_name.split('(ID:')[1].split(')')[0].strip()
            #     artistId = artist_id_map.get(artId2, 'Unknown')  # Use artist_id_map to fetch the UUID
            #     values_track_artist.append(f"('{trackId}',  '{artistId}', TRUE, NOW(), NOW())")
            # else:
            #     # Multiple artists, first one is main, others are not
            #     for i, artist in enumerate(artistNames):
            #         artId2 = artist.split('(ID:')[1].split(')')[0].strip()
            #         artistId = artist_id_map.get(artId2, 'Unknown')  # Fetch UUID from the map
            #         main = 'TRUE' if i == 0 else 'FALSE'
            #         values_track_artist.append(f"('{trackId}', '{artistId}', {main}, NOW(), NOW())")

    # Combine values for SQL insert queries
    insert_sql_album += ",\n".join(values_album) + ";"
    insert_sql_album_image += ",\n".join(values_album_image) + ";"
    insert_sql_track += ",\n".join(values_track) + ";"
    insert_sql_artist_song += ",\n".join(values_track_artist) + ";"

    with open(sql_file_path, 'a', encoding='utf-8') as file:
        file.write("\n\n\n\n")
        file.write(f"--------------------{nameArtist}")
        file.write("\n\n\n\n")
        file.write(insert_sql_album)
        file.write("\n\n\n\n")
hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL)']
# ['Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL) ', ' Karik (ID: 2Bwp23pD4UVsSkchHDZw4F)']
# ['Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL) ', ' Thanh Lam (ID: 5kG9gxVkkdrskVLhfblCjT) ', ' Tùng Dương (ID: 4rBvN6UImNzcY5abMKdAuw)']
# Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL)
# Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL)
# ['Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL) ', ' Cukak (ID: 3swW6OR2g7qTY3626sqVW4)']
# ['Karik (ID: 2Bwp23pD4UVsSkchHDZw4F) ', ' Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL) ', ' Only C (ID: 5GBXwBVQufRCmwI1bNRIUo)']
# Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL)
# Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL)
# ['Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL) ', ' Đen (ID: 1LEtM3AleYg1xabW6CRkpi)']
# Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL)
# Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL)
# Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL)
# ['Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL) ', ' Hoàng Rob (ID: 43qZrcVKZleWlmoBVRBPO8) ', ' Khắc Hưng (ID: 2mx5AAdmlMxMcrcd7AQh1j)']
# ['Rtee (ID: 73AUXZbgPiHjPbv66nGVq7) ', ' Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL)']
# ['Lam Truong (ID: 5tPrBvEiBBbSyMFz2u2ZMi) ', ' Tóc Tiên (ID: 4YkqEuVf1Jf2x2XDqJ2CvC) ', ' Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL) ', ' ERIK (ID: 1L1VfizWn4DkFt602yD80U) ', ' Karik (ID: 2Bwp23pD4UVsSkchHDZw4F)']
# ['Lam Truong (ID: 5tPrBvEiBBbSyMFz2u2ZMi) ', ' Tóc Tiên (ID: 4YkqEuVf1Jf2x2XDqJ2CvC) ', ' Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL) ', ' ERIK (ID: 1L1VfizWn4DkFt602yD80U) ', ' Karik (ID: 2Bwp23pD4UVsSkchHDZw4F)']
# ['Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL) ', ' JustaTee (ID: 3rjcQ5VIWCN4q7UFetzdeO) ', ' Đen (ID: 1LEtM3AleYg1xabW6CRkpi)']
# Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL)
# Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL)
# ['Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL) ', ' Kimmese (ID: 2gcRVD3JxVq4w09EZyjm9s)']
# ['Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL) ', ' Kimmese (ID: 2gcRVD3JxVq4w09EZyjm9s)']
# Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL)
# Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL)
# Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL)
# Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL)
# Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL)
# ['Wowy (ID: 4iFNiWhODcMZdmpNkxsTFp) ', ' Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL)']
# ['Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL) ', ' I.A.MY (ID: 3NZKDDKRHQCr8ejLSvEXA7)']
# Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL)
# Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL)
# Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL)
# Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL)
# Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL)
# Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL)
# Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL)
# Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL)
# Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL)
# Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL)
# Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL)
# Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL)
# Hoàng Thùy Linh (ID: 0r63ReVRjxrS4ATbLrdcrL)

# %%
import uuid

# Danh sách các thể loại nhạc
genres = ["acoustic", "afrobeat", "alt-rock", "alternative", "ambient", "anime", "black-metal", "bluegrass", "blues", "bossanova", "brazil", "breakbeat", "british", "cantopop", "chicago-house", "children", "chill", "classical", "club", "comedy", "country", "dance", "dancehall", "death-metal", "deep-house", "detroit-techno", "disco", "disney", "drum-and-bass", "dub", "dubstep", "edm", "electro", "electronic", "emo", "folk", "forro", "french", "funk", "garage", "german", "gospel", "goth", "grindcore", "groove", "grunge", "guitar", "happy", "hard-rock", "hardcore", "hardstyle", "heavy-metal", "hip-hop", "holidays", "honky-tonk", "house", "idm", "indian", "indie", "indie-pop", "industrial", "iranian", "j-dance", "j-idol", "j-pop", "j-rock", "jazz", "k-pop", "kids", "latin", "latino", "malay", "mandopop", "metal", "metal-misc", "metalcore", "minimal-techno", "movies", "mpb", "new-age", "new-release", "opera", "pagode", "party", "philippines-opm", "piano", "pop", "pop-film", "post-dubstep", "power-pop", "progressive-house", "psych-rock", "punk", "punk-rock", "r-n-b", "rainy-day", "reggae", "reggaeton", "road-trip", "rock", "rock-n-roll", "rockabilly", "romance", "sad", "salsa", "samba", "sertanejo", "show-tunes", "singer-songwriter", "ska", "sleep", "songwriter", "soul", "soundtracks", "spanish", "study", "summer", "swedish", "synth-pop", "tango", "techno", "trance", "trip-hop"]

# Tạo câu lệnh SQL để chèn dữ liệu vào bảng Genre
insert_sql_genre = 'INSERT INTO "Genre" ("id", "name") VALUES\n'

# Tạo danh sách các giá trị để chèn vào bảng
values_genre = []
values_genre2 = {}
# artist_id_map = {}
for genre in genres:
    genre_id = str(uuid.uuid4())
    values_genre.append(f"('{genre_id}', '{genre}')")
    values_genre2[genre_id] = genre

# Kết hợp các giá trị vào câu lệnh SQL
insert_sql_genre += ",\n".join(values_genre) + ";"

# Ghi câu lệnh SQL vào file
sql_file_path = 'D:/DUT/NAM4-KI1/PBL6/CRAWL/crawl-data-from-spotify/SQL2/genres_sql.sql'
with open(sql_file_path, 'w', encoding='utf-8') as file:
    file.write(insert_sql_genre)

print(f"Câu lệnh SQL đã được ghi vào file: {sql_file_path}")
# Out:
# Câu lệnh SQL đã được ghi vào file: D:/DUT/NAM4-KI1/PBL6/CRAWL/crawl-data-from-spotify/SQL2/genres_sql.sql

# %% [markdown]
# ### genre

# %%
import pandas as pd
import uuid

# Load artist information
artists = pd.read_csv('D:/DUT/NAM4-KI1/PBL6/CRAWL/crawl-data-from-spotify/Data-Artist/inf.csv')
# Danh sách các thể loại nhạc
genres = ["acoustic", "afrobeat", "alt-rock", "alternative", "ambient", "anime", "black-metal", "bluegrass", "blues", "bossanova", "brazil", "breakbeat", "british", "cantopop", "chicago-house", "children", "chill", "classical", "club", "comedy", "country", "dance", "dancehall", "death-metal", "deep-house", "detroit-techno", "disco", "disney", "drum-and-bass", "dub", "dubstep", "edm", "electro", "electronic", "emo", "folk", "forro", "french", "funk", "garage", "german", "gospel", "goth", "grindcore", "groove", "grunge", "guitar", "happy", "hard-rock", "hardcore", "hardstyle", "heavy-metal", "hip-hop", "holidays", "honky-tonk", "house", "idm", "indian", "indie", "indie-pop", "industrial", "iranian", "j-dance", "j-idol", "j-pop", "j-rock", "jazz", "k-pop", "kids", "latin", "latino", "malay", "mandopop", "metal", "metal-misc", "metalcore", "minimal-techno", "movies", "mpb", "new-age", "new-release", "opera", "pagode", "party", "philippines-opm", "piano", "pop", "pop-film", "post-dubstep", "power-pop", "progressive-house", "psych-rock", "punk", "punk-rock", "r-n-b", "rainy-day", "reggae", "reggaeton", "road-trip", "rock", "rock-n-roll", "rockabilly", "romance", "sad", "salsa", "samba", "sertanejo", "show-tunes", "singer-songwriter", "ska", "sleep", "songwriter", "soul", "soundtracks", "spanish", "study", "summer", "swedish", "synth-pop", "tango", "techno", "trance", "trip-hop"]

# Tạo câu lệnh SQL để chèn dữ liệu vào bảng Genre
insert_sql_genre = 'INSERT INTO "Genre" ("id", "name") VALUES\n'
# SQL INSERT template for the Artist table
insert_sql_artist = 'INSERT INTO "Artist" ("id", "name", "avatar", "bio", "createdAt", "updatedAt") VALUES\n'


# Tạo danh sách các giá trị để chèn vào bảng
values_genre = []
values_genre2 = {}
# artist_id_map = {}
for genre in genres:
    genre_id = str(uuid.uuid4())
    values_genre.append(f"('{genre_id}', '{genre}')")
    values_genre2[genre] = genre_id

# Kết hợp các giá trị vào câu lệnh SQL
insert_sql_genre += ",\n".join(values_genre) + ";"
# Ghi câu lệnh SQL vào file
sql_file_path = 'D:/DUT/NAM4-KI1/PBL6/CRAWL/crawl-data-from-spotify/SQL2/genres_sql.sql'
with open(sql_file_path, 'w', encoding='utf-8') as file:
    file.write(insert_sql_genre)
print(values_genre)
print(f"Câu lệnh SQL đã được ghi vào file: {sql_file_path}")


# print(artists.columns)
for index4, row4 in artists.iterrows():
    # print()
    gens = row4[' Genres'].split('||')
    for gen in gens:
        # print(gen)
        gen = gen.strip()
        if gen in values_genre2:
            genre_id = values_genre2[gen]
            # print(f"Thể loại '{gen}' đã được liên kết với ID {genre_id}.")






# Prepare artist insert values and a mapping between id2 and id (UUID)
values_artist = []
artist_id_map = {}
for index3, row3 in artists.iterrows():
    artist_uuid = str(uuid.uuid4()) 
    artist_id2 = row3['Artist ID']
    name = row3[' Artist Name'].strip()
    # avatar = row3[' Images'].split('||')[1].split('(')[0].strip()
    images = row3[' Images'].split('||')
    if len(images) > 1:
        avatar = images[1].split('(')[0].strip()
    else:
        avatar = 'Unknown'
    bio = 'Null'
    values_artist.append(f"('{artist_uuid}', '{name}', '{avatar}', '{bio}', NOW(), NOW())")
    
    # Store the mapping for use later
    artist_id_map[artist_id2] = artist_uuid


print(artist_id_map)


# Save the SQL queries to a file
sql_file_path = f'D:/DUT/NAM4-KI1/PBL6/CRAWL/crawl-data-from-spotify/SQL2/fullsql.sql'


insert_sql_artist += ",\n".join(values_artist) + ";"
with open(sql_file_path, 'w', encoding='utf-8') as file:
        file.write(insert_sql_artist)
        file.write("\n\n\n\n")


nameArtists = ['SonTungMTP', 'SOOBIN', 'PhanManhQuynh', 'NooPhuocThinh', 'HoangTon', 'HoangThuyLinh']

for nameArtist in nameArtists:
    # Load album and track data for the artist
    df = pd.read_csv(f'D:/DUT/NAM4-KI1/PBL6/CRAWL/crawl-data-from-spotify/Merge/{nameArtist}.csv')

    # SQL INSERT templates for Album, AlbumImage, Song, and ArtistSong tables
    insert_sql_album = 'INSERT INTO "Album" ("albumId",  "title", "releaseDate", "albumType", "createdAt", "updatedAt") VALUES\n'
    insert_sql_album_image = 'INSERT INTO "AlbumImage" ("albumId", "image", "size", "createdAt", "updatedAt") VALUES\n'
    insert_sql_track = 'INSERT INTO "Song" ("id", "albumId", "title", "duration", "lyric", "filePathAudio", "privacy", "uploadUserId", "createdAt", "updatedAt") VALUES\n'
    insert_sql_artist_song = 'INSERT INTO "ArtistSong" ("songId", "artistId", "main", "createdAt", "updatedAt") VALUES\n'

    # Prepare insert values for albums, album images, tracks, and artist-song relationships
    values_album = []
    values_album_image = []
    values_track = []
    values_track_artist = []

    # Remove duplicate albums
    unique_album = df.drop_duplicates(subset=['AlbumID'])

    for index, row in unique_album.iterrows():
        # Album details
        albumId = str(uuid.uuid4()) 
        albumIdTemp = row['AlbumID']
        
        values_album.append(f"('{albumId}', '{row['Album']}', '{row['ReleaseDate']}', '{row['AlbumType'].lower()}', NOW(), NOW())")

        # Album images
        images = row['AlbumImage'].split('||')
        for img in images:
            if '(' in img:
                img_url, img_size = img.split('(')
                img_url = img_url.strip()
                img_size = img_size.strip().split('size:')[1].strip().split(')')[0].strip()
                values_album_image.append(f"('{albumId}', '{img_url}', '{img_size}', NOW(), NOW())")
            else:
                # Handle case where image string does not contain '('
                img_url = img.strip()
                img_size = 0  # or any default value you prefer
                values_album_image.append(f"('{albumId}', '{row['AlbumID']}', '{img_url}', '{img_size}', NOW(), NOW())")

                
            # img_url, img_size = img.split('(')
            # img_url = img_url.strip()
            # img_size = img_size.strip().split('size:')[1].strip().split(')')[0].strip()
            # values_album_image.append(f"('{albumId}', '{img_url}', '{img_size}', NOW(), NOW())")

        # Tracks associated with the current album
        tracks_in_album = df[df['AlbumID'] == albumIdTemp]
        for _, track in tracks_in_album.iterrows():
            trackId = str(uuid.uuid4())
            values_track.append(f"('{trackId}', '{albumId}', '{track['TrackName']}', '{track['TrackDuration']}', 'lyric', '{track['audio_path']}', FALSE, 'Null', NOW(), NOW())")

            # Associate track with artists
            # artistNames = track['ArtistsName'].split('||')
            artistNames = track['ArtistsName']
            if pd.isna(artistNames):
                continue  # Skip if ArtistsName is NaN
            if "||" in artistNames:

                artistNames = artistNames.split('||')
                # Multiple artists, first one is main, others are not
                for i, artist in enumerate(artistNames):
                    artId2 = artist.split('(ID:')[1].split(')')[0].strip()
                    artistId = artist_id_map.get(artId2, 'Unknown')  # Fetch UUID from the map
                    main = 'TRUE' if i == 0 else 'FALSE'
                    values_track_artist.append(f"('{trackId}', '{artistId}', {main}, NOW(), NOW())")
            else: 
                artId2 = artistNames.split('(ID:')[1].split(')')[0].strip()
                artistId = artist_id_map.get(artId2, 'Unknown')  # Use artist_id_map to fetch the UUID
                values_track_artist.append(f"('{trackId}',  '{artistId}', TRUE, NOW(), NOW())")

            # print(artistNames)
            # if pd.isna(artistNames):
            #     continue  # Skip if ArtistsName is NaN
            # artistNames = artistNames.split('||')

            # Handle artist-song relation based on artistNames length
            if len(artistNames) == 1:
                # Only one artist, set main to TRUE
                artist_name = artistNames[0]
                # print(artist_name)
                artId2 = artist_name.split('(ID:')[1].split(')')[0].strip()
                artistId = artist_id_map.get(artId2, 'Unknown')  # Use artist_id_map to fetch the UUID
                values_track_artist.append(f"('{trackId}',  '{artistId}', TRUE, NOW(), NOW())")
            else:
                # Multiple artists, first one is main, others are not
                for i, artist in enumerate(artistNames):
                    artId2 = artist.split('(ID:')[1].split(')')[0].strip()
                    artistId = artist_id_map.get(artId2, 'Unknown')  # Fetch UUID from the map
                    main = 'TRUE' if i == 0 else 'FALSE'
                    values_track_artist.append(f"('{trackId}', '{artistId}', {main}, NOW(), NOW())")

    # Combine values for SQL insert queries
    insert_sql_album += ",\n".join(values_album) + ";"
    insert_sql_album_image += ",\n".join(values_album_image) + ";"
    insert_sql_track += ",\n".join(values_track) + ";"
    insert_sql_artist_song += ",\n".join(values_track_artist) + ";"

    with open(sql_file_path, 'a', encoding='utf-8') as file:
        file.write("\n\n\n\n")
        file.write(f"--------------------{nameArtist}")
        file.write("\n\n\n\n")
        file.write(insert_sql_album)
        file.write("\n\n\n\n")
        file.write(insert_sql_album_image)
        file.write("\n\n\n\n")
        file.write(insert_sql_track)
        file.write("\n\n\n\n")
        file.write(insert_sql_artist_song)
f3de-431a-9e69-ee1ab1dad20c', '4rBvN6UImNzcY5abMKdAuw': '64196c01-6412-4c8b-ac1a-1ad07b5dd652', '2FXC3k01G6Gw61bmprjgqS': 'd149e9db-7b8e-439f-be09-9d64695be6dc', '5HZtdKfC4xU0wvhEyYDWiY': '2844825d-a008-4ad8-bab6-e0943662401e', '4fCHhderLwLacsIOIKgu3J': '529bc338-ae5f-415a-94ca-e080fd0e778b', '5Xszvj310qgS7Fwn91Wvhu': 'fed8dccf-3ad7-4c5b-a1fe-e7a7fce87272', '43qZrcVKZleWlmoBVRBPO8': '83cdd351-56fe-4186-88f8-5458c37ee677', '3pxke5x7WfMfs5IwsSAh0u': '8ebf8a7f-2bac-49e1-98ee-b9dfa9e3579e', '4EqEodSfNgQPwoHxbdZlpT': '6e8abff3-ff13-4416-bbdd-2828a24175dc', '1b9USL8WQoqdSDSrdMNk8g': 'd048dfb9-dfed-489b-9807-388623ec31fd', '7pXKdkQsYFCMG2omRxheJ2': '71309417-d821-4eb0-a13b-8df4392b2428', '5UNWQJdUbO8Gbg9Qn3r52M': 'd48f961f-a1e6-40db-9501-e72122796051', '3mibIJiduF0MVLLAvHZAxw': '0830e58b-b3a6-4876-99bd-c9d7e79fbad5', '04MnOKOdhBexWQZC0kvCva': 'b83be2d3-005c-4dcf-8274-9dd4224a8b18', '3rjcQ5VIWCN4q7UFetzdeO': '23097fe6-3df6-4f4a-b882-ee0608eacef9', '7KHN9D81AGKzY7bUSL78FA': 'f0a3e5b0-acb1-499d-b1f6-b65f30bfd6eb', '53JNigMoziak3PfjdVcNLh': '43b6261f-07ee-4d2c-a5fe-c8ddb4491889', '67SfZJn4duJVXeVyjhOQni': '1a2d50f3-dbfd-418e-8ba6-0d9992c2b884', '4YkqEuVf1Jf2x2XDqJ2CvC': '317c3d45-9f65-487b-a41a-642466b05e3f', '3diftVOq7aEIebXKkC34oR': 'cf519335-534e-4159-b05d-0f8e996ecf00', '73AUXZbgPiHjPbv66nGVq7': '126ac1d7-16f4-420e-9a65-1b986a374249', '3o2irfEKlYwaT9uMaIUZjj': '0920f504-dce9-446e-b6e4-2cefab6c823a', '4x1fUORHa2EsxrQ6ZzAoQ0': 'eeee0728-d341-47db-92f4-cd4a04663736', '6tfKFH4RPLVvjJaeb5pVfI': 'be6ff984-e026-4a9b-a824-bae0712831ab', '3EPkqJFzEGSJWtGsu1Xwqt': 'b1d3aead-6ff ...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 172
#     169 else:
#     170     # Multiple artists, first one is main, others are not
#     171     for i, artist in enumerate(artistNames):
# --> 172         artId2 = artist.split('(ID:')[1].split(')')[0].strip()
#     173         artistId = artist_id_map.get(artId2, 'Unknown')  # Fetch UUID from the map
#     174         main = 'TRUE' if i == 0 else 'FALSE'
#
# IndexError: list index out of range

# %% [markdown]
# ### uuid

# %%
import uuid

# Tạo một UUID ngẫu nhiên
random_uuid = str(uuid.uuid4())

print(f"UUID ngẫu nhiên: {random_uuid}")
# Out:
# UUID ngẫu nhiên: be5a2d90-1032-45e2-98c4-6e1294629ae5
